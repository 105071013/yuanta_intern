# %% [markdown]
# ### predict label for topic : 訂單

# %%
from transformers import BertTokenizer
from transformers import BertForSequenceClassification

# %run C:/Users/user11/Desktop/3.Factor_desk/data_mining/utils/data_retriever.py
# %run C:/Users/user11/Desktop/3.Factor_desk/data_mining/utils/NewsDataset.py
# %run C:/Users/user11/Desktop/3.Factor_desk/data_mining/utils/predict_process.py
# Out:
# Using TensorFlow backend.

# %%
data_path  = './data/order.xlsx'
model_path = 'C:/Users/user11/Desktop/3.Factor_desk/data_mining/revenue_model'

# %%
## import data for labeling
df = pd.read_excel(data_path)
df = df.reset_index(drop=True)
df = df.dropna()

# %%
df = df[['titles', 'label_revised']]
df = df.rename(columns={'titles': 'contents', 'label_revised': 'label'})
df = df[['contents', 'label']]

df['contents']=df['contents'].apply(contents_trimmer,max_len=510)
df['label'] += 1

# %%
df
# Out:
#                                               contents  label
# 0      (3030)德律-重大訊息 說明媒體報導本公司前高階主管搬走FCT生產線搶訂單16人遭起訴乙案    0.0
# 1    (3037)欣興-重大訊息 公告本公司董事會決議通過追加109年度資本預算及長交期設備預下訂單金額    1.0
# 2    (3629)地心引力-重大訊息 公告本公司子公司GAMESWORD CO., LIMITED...    2.0
# 3    (3629)地心引力-重大訊息 公告本公司董事會決議通過授權遊戲事業群執行長兼營運長辦理後續...    2.0
# 4                            (5344)立衛-重大訊息 公告本公司接獲客戶訂單    2.0
# ..                                                 ...    ...
# 624                                    供應鏈力挺台積電：Q2訂單成長    2.0
# 625                             供應鏈重組 外銷訂單陸港生產降2.1個百分點    0.0
# 626                         保瑞原料藥疑慮已排除且加入新訂單 明年營運將優於今年    2.0
# 627                        信紘科去年EPS 1.15元；今年續優化訂單結構拚營運    2.0
# 628                            信紘科去年獲利年減六成 今年以優化訂單結構優先    1.0
#
# [621 rows x 2 columns]

# %%
## prediction through fine-tuned model (revenue)
tokenizer = BertTokenizer.from_pretrained(model_path)
model = BertForSequenceClassification.from_pretrained(model_path)

predict_dataloader = predict_data_preparation(df, tokenizer, batch_size = 32)
df = predict_process(model, predict_dataloader, df)
# Out:
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'only_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you may want to check this is the right behavior.
# ...

# %%
(df['label'] == df['predict_label']).sum() / len(df)
# Out:
# 0.7745571658615137

# %%
df
# Out:
#                                               contents  label  predict_label
# 0      (3030)德律-重大訊息 說明媒體報導本公司前高階主管搬走FCT生產線搶訂單16人遭起訴乙案    0.0              1
# 1    (3037)欣興-重大訊息 公告本公司董事會決議通過追加109年度資本預算及長交期設備預下訂單金額    1.0              1
# 2    (3629)地心引力-重大訊息 公告本公司子公司GAMESWORD CO., LIMITED...    2.0              1
# 3    (3629)地心引力-重大訊息 公告本公司董事會決議通過授權遊戲事業群執行長兼營運長辦理後續...    2.0              1
# 4                            (5344)立衛-重大訊息 公告本公司接獲客戶訂單    2.0              1
# ..                                                 ...    ...            ...
# 624                                    供應鏈力挺台積電：Q2訂單成長    2.0              2
# 625                             供應鏈重組 外銷訂單陸港生產降2.1個百分點    0.0              0
# 626                         保瑞原料藥疑慮已排除且加入新訂單 明年營運將優於今年    2.0              2
# 627                        信紘科去年EPS 1.15元；今年續優化訂單結構拚營運    2.0              2
# 628                            信紘科去年獲利年減六成 今年以優化訂單結構優先    1.0              0
#
# [621 rows x 3 columns]

# %%
df.to_csv('./data/auto_labeled/order_predict_label.csv', encoding='utf_8_sig')

# %%
df
# Out:
#                                               contents  label  predict_label
# 0    觸控晶片廠電去年營運表現亮麗，與獲利同創歷史新高，每股純益新台幣8.57元。義隆電表示，今年...      2              2
# 1    （3706）今（10）日公布今年1月合併營收約31億元，年增14.09%。不過，神達表示，1...      1              2
# 2    板卡廠映泰（2399）今（10）日公告，受影響，大陸子公司因交通問題員工返廠困難，將依實際人...      1              1
# 3    武漢肺炎疫情持續，中國大陸企業明（10）日能否順利復工、影響全球經濟走勢成為焦點，而部分產業...      2              2
# 4    中國武漢爆發新型冠狀病毒（2019-nCoV）疫情還無法控制下來，中國許多地方政府已下令封城...      1              1
# ..                                                 ...    ...            ...
# 201  經濟部統計，108年台灣的外銷訂單海外生產比率約52.6%，較107年增加0.2個百分點，主...      1              0
# 202  蘋果供應鏈的散熱機構件廠安力-KY今天召開，展望2020年，因終端客戶中國大陸通訊大廠訂單大...      2              2
# 203  新冠肺炎打亂全球供應鏈，法人圈近期也緊盯上半年業績大幅成長的伺服器等族群業績，在下半年表現，...      0              0
# 204  美國對抗仇恨言論行動延燒，星巴克等企業主抵制在社群網站投放廣告。美系外資認為，臉書和推特伺服...      1              1
# 205  金屬沖壓件廠安力-KY（5223）昨（30）日召開，安力指出，目前中國大陸的訂單持續增長，加...      2              2
#
# [206 rows x 3 columns]
